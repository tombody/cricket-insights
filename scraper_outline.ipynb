# %% [markdown]
# # Outline for cricket scorecard scraper

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
url = 'http://www.howstat.com/cricket/Statistics/Matches/MatchScorecard_ODI.asp?MatchCode='
page = '1619'

source = requests.get(f'{url}{page}').text
soup = BeautifulSoup(source, 'lxml')

# %% [markdown]
# ## Getting all of the data that repeats

# %%
repeatables = np.array([item.text.strip() for item in soup.find_all(class_="TextBlack8")])
date, location, result, rr_inn_1, rr_inn_2 = repeatables[[0,1,4,6,8]]

rr_inn_1 = float(rr_inn_1.split('@')[1].split('rpo')[0].strip())
rr_inn_2 = float(rr_inn_2.split('@')[1].split('rpo')[0].strip())

# %%
date, location, result, rr_inn_1, rr_inn_2
# Out:
# ('2nd January, 2000',
#  'Eden Park, Auckland',
#  'New Zealand won by 3 wickets [Duckworth-Lewis]',
#  5.36,
#  5.54)

# %%
repeatables_2 = np.array([item.text.strip() for item in soup.find_all(class_="TextBlackBold8")])
team_1, team_1_rr_wicks, team_1_runs, team_2, team_2_rr_wicks, team_2_runs = repeatables_2[[7, 15, 16, 25, 33, 34]]

try: 
    team_1_wicks_lost = int(team_1_rr_wicks.split('\r')[0].split('wickets')[0].strip())
except ValueError:
    team_1_wicks_lost = 10
team_1_rr = float(team_1_rr_wicks.split('@')[1].split('rpo')[0].strip())
team_1_runs = int(team_1_runs)

team_2 = team_2.split('\xa0')[0]
try: 
    team_2_wicks_lost = int(team_2_rr_wicks.split('\r')[0].split('wickets')[0].strip())
except ValueError:
    team_2_wicks_lost = 10
team_2_rr = float(team_2_rr_wicks.split('@')[1].split('rpo')[0].strip())
team_2_runs = int(team_2_runs)

team_1, team_1_rr, team_1_wicks_lost, team_1_runs, team_2, team_2_rr, team_2_wicks_lost, team_2_runs
# Out:
# ('West Indies', 5.36, 7, 268, 'New Zealand', 5.54, 7, 250)

# %%
# Determining the winner of each match (0-loss, 1-win, 2-draw)
if result.split(" ")[0] == "Sri":
        winner = "Sri Lanka"
elif result.split(" ")[0] == "New":
    winner = "New Zealand"
elif result.split(" ")[0] == "South":
    winner = "South Africa"
elif result.split(" ")[0] == "West":
    winner = "West Indies"
else:
    winner = result.split(" ")[0]

if winner == team_1:
    team_1_win = 1
    team_2_win = 0
elif winner == team_2:
    team_1_win = 0
    team_2_win = 1
else:
    team_1_win = 2
    team_2_win = 2

# %% [markdown]
# ## Getting all the non-repeatable data

# %%
# Making a list of the players
players = np.array([item.text for item in soup.find_all(class_="LinkOff")])
players = players[3:-2]
players
# Out:
# array(['S L Campbell', 'R D Jacobs', 'B C Lara', 'S Chanderpaul',
#        'R L Powell', 'F A Rose', 'N O Perry', 'J C Adams', 'M V Dillon',
#        'R D King', 'C A Walsh', 'D J Nash', 'C L Cairns', "S B O'Connor",
#        'C Z Harris', 'D L Vettori', 'N J Astle', 'C M Spearman',
#        'N J Astle', 'S P Fleming', 'C D McMillan', 'C L Cairns',
#        'C Z Harris', 'R G Twose', 'A C Parore', 'D J Nash', 'D L Vettori',
#        "S B O'Connor", 'C A Walsh', 'F A Rose', 'R D King', 'M V Dillon',
#        'N O Perry'], dtype='<U31')

# %%
players_team_1 = list(players[0:11])
players_team_1
# Out:
# ['S L Campbell',
#  'R D Jacobs',
#  'B C Lara',
#  'S Chanderpaul',
#  'R L Powell',
#  'F A Rose',
#  'N O Perry',
#  'J C Adams',
#  'M V Dillon',
#  'R D King',
#  'C A Walsh']

# %%
players_team_2 = [x for x in players if x not in players_team_1]
players_team_2 = list(set(players_team_2))
players_team_2
# Out:
# ['C M Spearman',
#  'A C Parore',
#  'N J Astle',
#  'D J Nash',
#  'R G Twose',
#  'C D McMillan',
#  'C Z Harris',
#  "S B O'Connor",
#  'D L Vettori',
#  'C L Cairns',
#  'S P Fleming']

# %%
# Grabbing all of the data from the html
tds = [item.text.strip() for item in soup.find('table').find_all('table')[4].find_all('table')[1].find_all('td')]
tds = np.array(list(map(lambda x: x.replace('\x86', '').replace('*',''),tds)))

# %%
# Grabing all of the player scorecard info
player_scorecards = []
used_index = []
for player in players:
    indices = np.where(tds==player)[0]
    if len(indices)==1:
        player_scorecards.append([tds[indices][0], tds[indices+1][0], 
                                  tds[indices+2][0], tds[indices+3][0], 
                                  tds[indices+4][0], tds[indices+5][0], 
                                  tds[indices+6][0]])
        used_index.append(indices[0])
    elif len(indices)==2 and indices[0] not in used_index:
        player_scorecards.append([tds[indices][0], tds[indices+1][0], 
                                  tds[indices+2][0], tds[indices+3][0], 
                                  tds[indices+4][0], tds[indices+5][0], 
                                  tds[indices+6][0]])
        used_index.append(indices[0])
    else:
        player_scorecards.append([tds[indices][1], tds[indices+1][1], 
                                  tds[indices+2][1], tds[indices+3][1], 
                                  tds[indices+4][1], tds[indices+5][1], 
                                  tds[indices+6][1]])

# Appending the date, location, and result for each player
for item in player_scorecards:
    item.append(date)
    item.append(location)
    item.append(result)

# %%
# Isolating the batters and bowlers from the scorecard
batters = []
bowlers = []

for item in player_scorecards:
    try:
        float(item[1])
        bowlers.append(item)
    except ValueError:
        batters.append(item)

# Adding the repeat data info for the batsmen
for batter in batters[0:11]:
    batter.append(1)
    batter.append(team_1)
    batter.append(team_1_rr)
    batter.append(team_1_wicks_lost)
    batter.append(team_1_runs)
    batter.append(team_1_win)

for batter in batters[11:]:
    batter.append(2)
    batter.append(team_2)
    batter.append(team_2_rr)
    batter.append(team_2_wicks_lost)
    batter.append(team_2_runs)
    batter.append(team_2_win)

# %%
# Removing wickets taken as % of team wickets
for x in bowlers:
    del x[6]

# Adding team name to bowler
for bowler in bowlers:
    if bowler[0] in players_team_1:
        bowler.append(2)
        bowler.append(team_1)
        bowler.append(team_2_rr)
        bowler.append(team_2_wicks_lost)
        bowler.append(team_2_runs)
        bowler.append(team_1_win)
    elif bowler[0] in players_team_2:
        bowler.append(1)
        bowler.append(team_2)
        bowler.append(team_1_rr)
        bowler.append(team_1_wicks_lost)
        bowler.append(team_1_runs)
        bowler.append(team_2_win)

# %%
batters_columns = ['Player', 'Dismissal', 'Runs', 'BallsFaced', 'Fours', 'Sixes', 
                   'StrikeRate', 'Date', 'Location', 'Result', 'Innings', 
                   'Team' , 'BatSideRR', 'BatSideWicksLost', 'BatSideScore', 'Win']
batters_df = pd.DataFrame(batters, columns=batters_columns)
batters_df
# Out:
#            Player                Dismissal Runs BallsFaced Fours Sixes  \
# 0    S L Campbell     st Parore b  Vettori   51         67     6     0
# 1      R D Jacobs            lbw b  Harris   65         61     7     2
# 2        B C Lara      c  Nash b  O'Connor   76         81     3     2
# 3   S Chanderpaul                  run out   11         40     0     0
# 4      R L Powell         c  Twose b  Nash   35         30     3     2
# 5        F A Rose  c  McMillan b  O'Connor    2          6     0     0
# 6       N O Perry                  not out    2          5     0     0
# 7       J C Adams      c  Fleming b  Astle    0          1     0     0
# 8      M V Dillon                  not out   13          9     2     0
# 9        R D King
# 10      C A Walsh
# 11   C M Spearman        c Jacobs b  Walsh   25         19     4     1
# 12      N J Astle                  b  Rose   77        101     7     1
# 13    S P Fleming         c Jacobs b  King    1          7     0     0
# 14   C D McMillan          c  Rose b  King    1         11     0     0
# 15     C L Cairns        c  Powell b  Rose   75         88     2     6
# 16     C Z Harris                  not out   22         21     2     0
# 17      R G Twose         c Jacobs b  Rose    6          8     0     0
# 18     A C Parore        c  Dillon b  King    4         10     0     0
# 19       D J Nash                  not out   12         13     0     0
# 20    D L Vettori
# 21   S B O'Connor
#
#    StrikeRate               Date             Location  \
# 0       76.12  2nd January, 2000  Eden Park, Auckland
# 1      106.56  2nd January, 2000  Eden Park, Auckland
# 2       93.83  2nd January, 2000  Eden Park, Auckland
# 3       27.50  2nd January, 2000  Eden Park, Auckland
# 4      116.67  2nd January, 2000  Eden Park, Auckland
# 5       33.33  2nd January, 2000  Eden Park, Auckland
# 6       40.00  2nd January, 2000  Eden Park, Auckland
# 7        0.00  2nd January, 2000  Eden Park, Auckland
# 8      144.44  2nd January, 2000  Eden Park, Auckland
# 9              2nd January, 2000  Eden Park, Auckland
# 10             2nd January, 2000  Eden Park, Auckland
# 11     131.58  2nd January, 2000  Eden Park, Auckland
# 12      76.24  2nd January, 2000  Eden Park, Auckland
# 13      14.29  2nd January, 2000  Eden Park, Auckland
# 14       9.09  2nd January, 2000  Eden Park, Auckland
# 15      85.23  2nd January, 2000  Eden Park, Auckland
# 16     104.76  2nd January, 2000  Eden Park, Auckland
# 17      75.00  2nd January, 2000  Eden Park, Auckland
# 18      40.00  2nd January, 2000  Eden Park, Auckland
# 19      92.31  2nd January, 2000  Eden Park, Auckland
# 20             2nd January, 2000  Eden Park, Auckland
# 21             2nd January, 2000  Eden Park, Auckland
#
#                                             Result  Innings         Team  \
# 0   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 1   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 2   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 3   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 4   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 5   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 6   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 7   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 8   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 9   New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 10  New Zealand won by 3 wickets [Duckworth-Lewis]        1  West Indies
# 11  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 12  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 13  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 14  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 15  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 16  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 17  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 18  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 19  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 20  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
# 21  New Zealand won by 3 wickets [Duckworth-Lewis]        2  New Zealand
#
#     BatSideRR  BatSideWicksLost  BatSideScore  Win
# 0        5.36                 7           268    0
# 1        5.36                 7           268    0
# 2        5.36                 7           268    0
# 3        5.36                 7           268    0
# 4        5.36                 7           268    0
# 5        5.36                 7           268    0
# 6        5.36                 7           268    0
# 7        5.36                 7           268    0
# 8        5.36                 7           268    0
# 9        5.36                 7           268    0
# 10       5.36                 7           268    0
# 11       5.54                 7           250    1
# 12       5.54                 7           250    1
# 13       5.54                 7           250    1
# 14       5.54                 7           250    1
# 15       5.54                 7           250    1
# 16       5.54                 7           250    1
# 17       5.54                 7           250    1
# 18       5.54                 7           250    1
# 19       5.54                 7           250    1
# 20       5.54                 7           250    1
# 21       5.54                 7           250    1

# %%
bowlers_columns = ['Player', 'Overs', 'Maidens', 'Runs', 'Wickets', 'EconRate', 
                   'Date', 'Location', 'Result', 'Innings', 'Team', 
                   'BatSideRR', 'BatSideWicketsLost', 'BatSideScore', 'Win']
bowlers_df = pd.DataFrame(bowlers, columns=bowlers_columns)
bowlers_df
# Out:
#           Player Overs Maidens Runs Wickets EconRate               Date  \
# 0       D J Nash   8.0       0   62       1     7.75  2nd January, 2000
# 1     C L Cairns   5.0       0   29       0     5.80  2nd January, 2000
# 2   S B O'Connor   8.0       0   62       2     7.75  2nd January, 2000
# 3     C Z Harris  10.0       0   40       1     4.00  2nd January, 2000
# 4    D L Vettori  10.0       1   28       1     2.80  2nd January, 2000
# 5      N J Astle   9.0       0   37       1     4.11  2nd January, 2000
# 6      C A Walsh  10.0       0   48       1     4.80  2nd January, 2000
# 7       F A Rose   9.0       0   71       3     7.89  2nd January, 2000
# 8       R D King   8.1       3   24       3     2.94  2nd January, 2000
# 9     M V Dillon   9.0       1   41       0     4.56  2nd January, 2000
# 10     N O Perry   9.0       0   52       0     5.78  2nd January, 2000
#
#                Location                                          Result  \
# 0   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 1   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 2   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 3   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 4   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 5   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 6   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 7   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 8   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 9   Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
# 10  Eden Park, Auckland  New Zealand won by 3 wickets [Duckworth-Lewis]
#
#     Innings         Team  BatSideRR  BatSideWicketsLost  BatSideScore  Win
# 0         1  New Zealand       5.36                   7           268    1
# 1         1  New Zealand       5.36                   7           268    1
# 2         1  New Zealand       5.36                   7           268    1
# 3         1  New Zealand       5.36                   7           268    1
# 4         1  New Zealand       5.36                   7           268    1
# 5         1  New Zealand       5.36                   7           268    1
# 6         2  West Indies       5.54                   7           250    0
# 7         2  West Indies       5.54                   7           250    0
# 8         2  West Indies       5.54                   7           250    0
# 9         2  West Indies       5.54                   7           250    0
# 10        2  West Indies       5.54                   7           250    0
