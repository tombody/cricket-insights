# %% [markdown]
# # Outline for cricket scorecard scraper

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
page = '1627'

source = requests.get(f'http://www.howstat.com/cricket/Statistics/Matches/MatchScorecard_ODI.asp?MatchCode={page}').text

soup = BeautifulSoup(source, 'lxml')

# %% [markdown]
# ## Getting all of the data that repeats

# %%
repeatables = np.array([item.text.strip() for item in soup.find_all(class_="TextBlack8")])
date, location, result, rr_inn_1, rr_inn_2 = repeatables[[0,1,4,6,8]]
rr_inn_1 = float(rr_inn_1.split('@')[1].split('rpo')[0].strip())
rr_inn_2 = float(rr_inn_2.split('@')[1].split('rpo')[0].strip())

# %%
date, location, result, rr_inn_1, rr_inn_2
# Out:
# ('12th January, 2000',
#  'Melbourne Cricket Ground, Melbourne',
#  'Australia won by 28 runs',
#  5.38,
#  4.82)

# %%
repeatables_2 = np.array([item.text.strip() for item in soup.find_all(class_="TextBlackBold8")])
team_1, team_1_rr_wicks, team_1_runs, team_2, team_2_rr_wicks, team_2_runs = repeatables_2[[7, 15, 16, 25, 33, 34]]

team_1_wicks_lost = int(team_1_rr_wicks.split('\r')[0].split('wickets')[0].strip())
team_1_rr = float(team_1_rr_wicks.split('@')[1].split('rpo')[0].strip())
team_1_runs = int(team_1_runs)

team_2 = team_2.split('\xa0')[0]
team_2_wicks_lost = int(team_2_rr_wicks.split('\r')[0].split('wickets')[0].strip())
team_2_rr = float(team_2_rr_wicks.split('@')[1].split('rpo')[0].strip())
team_2_runs = int(team_2_runs)

team_1, team_1_rr, team_1_wicks_lost, team_1_runs, team_2, team_2_rr, team_2_wicks_lost, team_2_runs
# Out:
# ('Australia', 5.38, 7, 269, 'India', 4.82, 6, 241)

# %%
# Determining the winner of each match (0-loss, 1-win, 2-draw)
winner = result.split(" ")[0]

if winner == team_1:
    team_1_win = 1
    team_2_win = 0
elif winner == team_2:
    team_1_win = 0
    team_2_win = 1
else:
    team_1_win = 2
    team_2_win = 2

# %% [markdown]
# ## Getting all the non-repeatable data

# %%
# Making a list of the players
players = np.array([item.text for item in soup.find_all(class_="LinkOff")])
players = players[3:-2]
players
# Out:
# array(['M E Waugh', 'A C Gilchrist', 'R T Ponting', 'M G Bevan',
#        'S R Waugh', 'D R Martyn', 'A Symonds', 'S Lee', 'D W Fleming',
#        'B Lee', 'G D McGrath', 'J Srinath', 'A B Agarkar', 'B K V Prasad',
#        'S R Tendulkar', 'A Kumble', 'R R Singh', 'S C Ganguly',
#        'V V S Laxman', 'S C Ganguly', 'S S Dighe', 'S R Tendulkar',
#        'R Dravid', 'R R Singh', 'J J Martin', 'A B Agarkar', 'A Kumble',
#        'J Srinath', 'B K V Prasad', 'G D McGrath', 'D W Fleming', 'B Lee',
#        'S Lee', 'A Symonds', 'D R Martyn'], dtype='<U31')

# %%
players_team_1 = list(players[0:11])
players_team_1
# Out:
# ['M E Waugh',
#  'A C Gilchrist',
#  'R T Ponting',
#  'M G Bevan',
#  'S R Waugh',
#  'D R Martyn',
#  'A Symonds',
#  'S Lee',
#  'D W Fleming',
#  'B Lee',
#  'G D McGrath']

# %%
players_team_2 = [x for x in players if x not in players_team_1]
players_team_2 = list(set(players_team_2))
players_team_2
# Out:
# ['J Srinath',
#  'A B Agarkar',
#  'S S Dighe',
#  'S R Tendulkar',
#  'S C Ganguly',
#  'B K V Prasad',
#  'R Dravid',
#  'V V S Laxman',
#  'R R Singh',
#  'A Kumble',
#  'J J Martin']

# %%
# Grabbing all of the data from the html
tds = [item.text.strip() for item in soup.find('table').find_all('table')[4].find_all('table')[1].find_all('td')]
tds = np.array(list(map(lambda x: x.replace('\x86', '').replace('*',''),tds)))

# %%
# Grabing all of the player scorecard info
player_scorecards = []
used_index = []
for player in players:
    indices = np.where(tds==player)[0]
    if len(indices)==1:
        player_scorecards.append([tds[indices][0], tds[indices+1][0], 
                                  tds[indices+2][0], tds[indices+3][0], 
                                  tds[indices+4][0], tds[indices+5][0], 
                                  tds[indices+6][0]])
        used_index.append(indices[0])
    elif len(indices)==2 and indices[0] not in used_index:
        player_scorecards.append([tds[indices][0], tds[indices+1][0], 
                                  tds[indices+2][0], tds[indices+3][0], 
                                  tds[indices+4][0], tds[indices+5][0], 
                                  tds[indices+6][0]])
        used_index.append(indices[0])
    else:
        player_scorecards.append([tds[indices][1], tds[indices+1][1], 
                                  tds[indices+2][1], tds[indices+3][1], 
                                  tds[indices+4][1], tds[indices+5][1], 
                                  tds[indices+6][1]])

# Appending the date, location, and result for each player
for item in player_scorecards:
    item.append(date)
    item.append(location)
    item.append(result)

# %%
# Isolating the batters and bowlers from the scorecard
batters = []
bowlers = []

for item in player_scorecards:
    try:
        float(item[1])
        bowlers.append(item)
    except ValueError:
        batters.append(item)

# Adding the repeat data info for the batsmen
for batter in batters[0:11]:
    batter.append(1)
    batter.append(team_1)
    batter.append(team_1_rr)
    batter.append(team_1_wicks_lost)
    batter.append(team_1_runs)
    batter.append(team_1_win)

for batter in batters[11:]:
    batter.append(2)
    batter.append(team_2)
    batter.append(team_2_rr)
    batter.append(team_2_wicks_lost)
    batter.append(team_2_runs)
    batter.append(team_2_win)

# %%
# Removing wickets taken as % of team wickets
for x in bowlers:
    del x[6]

# Adding team name to bowler
for bowler in bowlers:
    if bowler[0] in players_team_1:
        bowler.append(2)
        bowler.append(team_1)
        bowler.append(team_2_rr)
        bowler.append(team_2_wicks_lost)
        bowler.append(team_2_runs)
        bowler.append(team_1_win)
    elif bowler[0] in players_team_2:
        bowler.append(1)
        bowler.append(team_2)
        bowler.append(team_1_rr)
        bowler.append(team_1_wicks_lost)
        bowler.append(team_1_runs)
        bowler.append(team_2_win)

# %%
batters_columns = ['Player', 'Dismissal', 'Runs', 'BallsFaced', 'Fours', 'Sixes', 
                   'StrikeRate', 'Date', 'Location', 'Result', 'Innings', 
                   'Team' , 'BatSideRR', 'BatSideWicksLost', 'BatSideScore', 'Win']
batters_df = pd.DataFrame(batters, columns=batters_columns)
batters_df
# Out:
#            Player                Dismissal Runs BallsFaced Fours Sixes  \
# 0       M E Waugh     c  Laxman b  Agarkar    7         15     1     0
# 1   A C Gilchrist     c  Laxman b  Srinath    3          2     0     0
# 2     R T Ponting  c  Tendulkar b  Srinath  115        121     9     1
# 3       M G Bevan      c  Agarkar b  Singh   41         54     3     0
# 4       S R Waugh                  run out   23         31     3     0
# 5      D R Martyn   c  Tendulkar b  Kumble   30         45     0     0
# 6       A Symonds                  run out    3          4     0     0
# 7           S Lee                  not out   22         15     0     1
# 8     D W Fleming                  not out   14         13     0     0
# 9           B Lee
# 10    G D McGrath
# 11   V V S Laxman   c Gilchrist b  McGrath    2         15     0     0
# 12    S C Ganguly                  run out  100        127    10     0
# 13      S S Dighe      c  Waugh b  Fleming    3         25     0     0
# 14  S R Tendulkar                  run out   12         11     2     0
# 15       R Dravid         c  Martyn b  Lee   60         85     2     0
# 16      R R Singh                  not out   33         35     1     1
# 17     J J Martin                  run out    0          1     0     0
# 18    A B Agarkar                  not out    6          8     0     0
# 19       A Kumble
# 20      J Srinath
# 21   B K V Prasad
#
#    StrikeRate                Date                             Location  \
# 0       46.67  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 1      150.00  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 2       95.04  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 3       75.93  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 4       74.19  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 5       66.67  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 6       75.00  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 7      146.67  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 8      107.69  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 9              12th January, 2000  Melbourne Cricket Ground, Melbourne
# 10             12th January, 2000  Melbourne Cricket Ground, Melbourne
# 11      13.33  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 12      78.74  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 13      12.00  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 14     109.09  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 15      70.59  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 16      94.29  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 17       0.00  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 18      75.00  12th January, 2000  Melbourne Cricket Ground, Melbourne
# 19             12th January, 2000  Melbourne Cricket Ground, Melbourne
# 20             12th January, 2000  Melbourne Cricket Ground, Melbourne
# 21             12th January, 2000  Melbourne Cricket Ground, Melbourne
#
#                       Result  Innings       Team  BatSideRR  BatSideWicksLost  \
# 0   Australia won by 28 runs        1  Australia       5.38                 7
# 1   Australia won by 28 runs        1  Australia       5.38                 7
# 2   Australia won by 28 runs        1  Australia       5.38                 7
# 3   Australia won by 28 runs        1  Australia       5.38                 7
# 4   Australia won by 28 runs        1  Australia       5.38                 7
# 5   Australia won by 28 runs        1  Australia       5.38                 7
# 6   Australia won by 28 runs        1  Australia       5.38                 7
# 7   Australia won by 28 runs        1  Australia       5.38                 7
# 8   Australia won by 28 runs        1  Australia       5.38                 7
# 9   Australia won by 28 runs        1  Australia       5.38                 7
# 10  Australia won by 28 runs        1  Australia       5.38                 7
# 11  Australia won by 28 runs        2      India       4.82                 6
# 12  Australia won by 28 runs        2      India       4.82                 6
# 13  Australia won by 28 runs        2      India       4.82                 6
# 14  Australia won by 28 runs        2      India       4.82                 6
# 15  Australia won by 28 runs        2      India       4.82                 6
# 16  Australia won by 28 runs        2      India       4.82                 6
# 17  Australia won by 28 runs        2      India       4.82                 6
# 18  Australia won by 28 runs        2      India       4.82                 6
# 19  Australia won by 28 runs        2      India       4.82                 6
# 20  Australia won by 28 runs        2      India       4.82                 6
# 21  Australia won by 28 runs        2      India       4.82                 6
#
#     BatSideScore  Win
# 0            269    1
# 1            269    1
# 2            269    1
# 3            269    1
# 4            269    1
# 5            269    1
# 6            269    1
# 7            269    1
# 8            269    1
# 9            269    1
# 10           269    1
# 11           241    0
# 12           241    0
# 13           241    0
# 14           241    0
# 15           241    0
# 16           241    0
# 17           241    0
# 18           241    0
# 19           241    0
# 20           241    0
# 21           241    0

# %%
bowlers_columns = ['Player', 'Overs', 'Maidens', 'Runs', 'Wickets', 'EconRate', 
                   'Date', 'Location', 'Result', 'Innings', 'Team', 
                   'BatSideRR', 'BatSideWicketsLost', 'BatSideScore', 'Win']
bowlers_df = pd.DataFrame(bowlers, columns=bowlers_columns)
bowlers_df
# Out:
#            Player Overs Maidens Runs Wickets EconRate                Date  \
# 0       J Srinath  10.0       0   52       2     5.20  12th January, 2000
# 1     A B Agarkar   9.0       0   47       1     5.22  12th January, 2000
# 2    B K V Prasad  10.0       0   52       0     5.20  12th January, 2000
# 3   S R Tendulkar   3.0       0   23       0     7.67  12th January, 2000
# 4        A Kumble  10.0       0   57       1     5.70  12th January, 2000
# 5       R R Singh   3.0       0   19       1     6.33  12th January, 2000
# 6     S C Ganguly   5.0       0   16       0     3.20  12th January, 2000
# 7     G D McGrath  10.0       1   32       1     3.20  12th January, 2000
# 8     D W Fleming  10.0       1   39       1     3.90  12th January, 2000
# 9           B Lee  10.0       0   49       0     4.90  12th January, 2000
# 10          S Lee  10.0       0   57       1     5.70  12th January, 2000
# 11      A Symonds   5.0       0   28       0     5.60  12th January, 2000
# 12     D R Martyn   5.0       0   28       0     5.60  12th January, 2000
#
#                                Location                    Result  Innings  \
# 0   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 1   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 2   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 3   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 4   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 5   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 6   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        1
# 7   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        2
# 8   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        2
# 9   Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        2
# 10  Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        2
# 11  Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        2
# 12  Melbourne Cricket Ground, Melbourne  Australia won by 28 runs        2
#
#          Team  BatSideRR  BatSideWicketsLost  BatSideScore  Win
# 0       India       5.38                   7           269    0
# 1       India       5.38                   7           269    0
# 2       India       5.38                   7           269    0
# 3       India       5.38                   7           269    0
# 4       India       5.38                   7           269    0
# 5       India       5.38                   7           269    0
# 6       India       5.38                   7           269    0
# 7   Australia       4.82                   6           241    1
# 8   Australia       4.82                   6           241    1
# 9   Australia       4.82                   6           241    1
# 10  Australia       4.82                   6           241    1
# 11  Australia       4.82                   6           241    1
# 12  Australia       4.82                   6           241    1
